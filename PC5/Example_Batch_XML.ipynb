# %% [markdown]
# **Install & import packages**

# %%
import json
import requests
import pandas
from markdown import markdown
from IPython.display import Markdown

import xml.etree.ElementTree as ET    # Used for parsing XML files (like BeautifulSoup for HTML)
import pandas as pd

from pathlib import Path
from typing import Dict, List, Optional, Tuple
import re

# %% [markdown]
# ---
#
# <br>
#
# # Fetch PDF
#
# (not used)

# %%
# 1. Define URL to PDF (or XML) file
pdf_url = 'https://nsearchives.nseindia.com/corporate/BFUTILITIE_27112025155734_BRSR_BFUL_27112025.pdf'
pdf_file = pdf_url.split('/')[-1].split('.')[0]

# 2. Make GET request to fetch the PDF file
response = requests.get(pdf_url, headers={'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36'})

# 3. Check if our request was successful (Status 200), if so, save to a file.
if response.status_code == 200:
    with open('BFUTILITIE_27112025155734_BRSR_BFUL_27112025.pdf', 'wb') as f:
        f.write(response.content)
    print('PDF downloaded successfully.')
else:
    print('Failed to download file. Status code:', response.status_code)
# Out:
# PDF downloaded successfully.

# %% [markdown]
# <br>
#
# ### Fetch XML

# %%
# 1. Define URL to XML file
xml_url = 'https://nsearchives.nseindia.com/corporate/xbrl/BRSR_1580445_27112025035801_WEB.xml'
xml_file = xml_url.split('/')[-1]  # Get just the file name & endpoint (e.g. 'xyza.csv')

# 2. Make GET request to fetch the XML file
response = requests.get(xml_url, headers={'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36'})

# 3. Check if our request was successful (Status 200), if so, save to a file.
if response.status_code == 200:

    with open(f'{xml_file}', 'wb') as f:
        f.write(response.content)

    print('XML (XBRL) downloaded successfully.')
else:
    print('Failed to download file. Status code:', response.status_code)
# Out:
# XML (XBRL) downloaded successfully.

# %% [markdown]
# <br><br><br>
#
# # Extract from XML

# %% [markdown]
# Convert XBRL file to a flat DataFrame:
#
# - Every row is a value given in the report.
# - `Element Name` corresponds to each unique table (or headline value, like company name).
# - `Period/Context` relates to each value in a given table.
#
#
# So, to filter the dataframe for a specific value, we need to provide both the `Element Name` and `Period/Context`.
#
# <br>
#
# Interesting tables in report:
# - Table 20:
#   - 20A: `NumberOfEmployeesOrWorkersIncludingDifferentlyAbled`
#   - 20B: `NumberOfDifferentlyAbledEmployeesOrWorkers`

# %%
tree = ET.parse(xml_file)
root = tree.getroot()

# Structural elements to skip (not actual data facts)
skip_tags = {
    'xbrl', 'context', 'entity', 'identifier', 'period', 'startDate',
    'endDate', 'instant', 'scenario', 'typedMember', 'unit', 'measure',
    'schemaRef', 'segment'
}

rows = []
for elem in root.iter():
    # Extract local name from namespaced tag
    tag = elem.tag.split('}')[-1] if '}' in elem.tag else elem.tag

    # Skip structural elements
    if tag in skip_tags:
        continue

    # Skip domain definition elements
    if 'Domain' in tag and elem.text and 'Domain' in elem.text:
        continue

    # Get XBRL attributes
    ctx = elem.attrib.get('contextRef', '')
    unit = elem.attrib.get('unitRef', '')
    decimals = elem.attrib.get('decimals', '')

    # Only include actual facts (elements with contextRef)
    if ctx and elem.text is not None:
        rows.append({
            'Element Name': tag,
            'Period/Context': ctx,
            'Unit': unit,
            'Decimals': decimals,
            'Value': elem.text.strip()
        })

df = pd.DataFrame(rows)
df
# Out:
#                                            Element Name Period/Context Unit  \
# 0                               CorporateIdentityNumber        DCYMain
# 1                                      NameOfTheCompany        ICYMain
# 2                                   DateOfIncorporation        DCYMain
# 3                    AddressOfRegisteredOfficeOfCompany        DCYMain
# 4                     AddressOfCorporateOfficeOfCompany        DCYMain
# ...                                                 ...            ...  ...
# 1499  MechanismsInPlaceToInformConsumersOfAnyRiskOfD...        DCYMain
# 1500  DoesTheEntityDisplayProductInformationOnThePro...        DCYMain
# 1501  DetailsOfProductInformationOnTheProductOverAnd...        DCYMain
# 1502  DidYourEntityCarryOutAnySurveyWithRegardToCons...        DCYMain
# 1503  TheEntityHasNotApplicableCarryOutAnySurveyWith...        DCYMain
#
#      Decimals                                              Value
# 0                                          L74899DL1993GOI053677
# 1                                                   IFCI Limited
# 2                                                     1993-05-21
# 3              IFCI Limited, IFCI Tower, 61 Nehru Place, New ...
# 4              IFCI Limited, IFCI Tower, 61 Nehru Place, New ...
# ...       ...                                                ...
# 1499           Any risk of disruption/discontinuation of esse...
# 1500                                                         Yes
# 1501           The Company being an NBFC offers various finan...
# 1502                                                          NA
# 1503                                              Not Applicable
#
# [1504 rows x 5 columns]

# %% [markdown]
# Elements, Period/Context:
# - CorporateIdentityNumber, DCYMain
# - NameOfTheCompany, ICYMain

# %%
df[df['Period']]

# %%
# Search for elements matching some text
df[df['Element Name'].str.contains('employee', case=False)]
# Out:
#                                            Element Name  \
# 39    NumberOfEmployeesOrWorkersIncludingDifferently...
# 40    NumberOfEmployeesOrWorkersIncludingDifferently...
# 41    PercentageOfEmployeesOrWorkersIncludingDiffere...
# 42    NumberOfEmployeesOrWorkersIncludingDifferently...
# 43    PercentageOfEmployeesOrWorkersIncludingDiffere...
# ...                                                 ...
# 1198  MedianOfRemunerationOrSalaryOrWagesOfEmployees...
# 1199  NumberOfEmployeesOtherThanBodAndKMPForRemunera...
# 1200  MedianOfRemunerationOrSalaryOrWagesOfEmployees...
# 1241  AverageNumberOfFemaleEmployeesOrWorkersAtTheBe...
# 1242  AverageNumberOfFemaleEmployeesOrWorkersAtTheBe...
#
#                           Period/Context  Unit Decimals   Value
# 39    D_Gender_PermanentEmployees_TableA  pure        0     116
# 40      D_Male_PermanentEmployees_TableA  pure        0      77
# 41      D_Male_PermanentEmployees_TableA  pure      INF  0.6638
# 42    D_Female_PermanentEmployees_TableA  pure        0      39
# 43    D_Female_PermanentEmployees_TableA  pure      INF  0.3363
# ...                                  ...   ...      ...     ...
# 1198                         D_Female_p5   INR        0      34
# 1199                    D_OtherGender_p5  pure        0       0
# 1200                    D_OtherGender_p5   INR        0       0
# 1241                             DCYMain  pure        0       0
# 1242                             DPYMain  pure        0       0
#
# [657 rows x 5 columns]

# %%
df['Element Name'].unique()
# Out:
# array(['CorporateIdentityNumber', 'NameOfTheCompany',
#        'DateOfIncorporation', 'AddressOfRegisteredOfficeOfCompany',
#        'AddressOfCorporateOfficeOfCompany', 'EMailOfTheCompany',
#        'TelephoneOfCompany', 'WebsiteOfCompany',
#        'DateOfStartOfFinancialYear', 'DateOfEndOfFinancialYear',
#        'DateOfStartOfPreviousYear', 'DateOfEndOfPreviousYear',
#        'DateOfStartOfPriorToPreviousYear',
#        'DateOfEndOfPriorToPreviousYear', 'ValueOfSharesPaidUp',
#        'NameOfContactPerson', 'ContactNumberOfContactPerson',
#        'EMailOfContactPerson', 'ReportingBoundary',
#        'WhetherTheCompanyHasUndertakenAssessmentOrAssuranceOfTheBRSRCore',
#        'NotesGeneralDisclosureExplanatoryTextBlock',
#        'NameOfStockExchangeWhereTheCompanyIsListed',
#        'DescriptionOfMainActivity', 'DescriptionOfBusinessActivity',
#        'PercentageOfTotalTurnoverForBusinessActivities',
#        'ProductOrServiceSoldByTheEntity',
#        'NICCodeOfProductOrServiceSoldByTheEntity',
#        'PercentageOfTotalTurnoverForProductOrServiceSold',
#        'NumberOfLocations', 'NumberOfStatesWhereMarketServedByTheEntity',
#        'NumberOfCountriesWhereMarketServedByTheEntity',
#        'PercentageOfContributionOfExportsInTheTotalTurnoverOfTheEntity',
#        'ABriefOnTypesOfCustomersExplanatoryTextBlock',
#        'NumberOfEmployeesOrWorkersIncludingDifferentlyAbled',
#        'PercentageOfEmployeesOrWorkersIncludingDifferentlyAbled',
#        'NumberOfDifferentlyAbledEmployeesOrWorkers',
#        'PercentageOfDifferentlyAbledEmployeesOrWorkers',
#        'TotalNumberOfBoardOfDirectors', 'NumberOfFemaleBoardOfDirectors',
#        'PercentageOfFemaleBoardOfDirectors',
#        'TotalNumberOfKeyManagementPersonnel',
#        'NumberOfFemaleKeyManagementPersonnel',
#        'PercentageOfFemaleKeyManagementPersonnel', 'TurnoverRate',
#        'WhetherCSRIsApplicableAsPerSection135OfCompaniesAct2013',
#        'Turnover', 'NetWorth',
#        'NameOfTheHoldingOrSubsidiaryAssociateCompaniesOrJointVentures',
#        'CategoryOfCompany', 'PercentageOfSharesHeldByListedEntity',
#        'DoesCompanyParticipateInTheBusinessResponsibilityInitiativesOfTheListedEntity',
#        'GrievanceRedressalMechanismInPlace',
#        'DetailsForGrievanceRedressalMechanismInPlaceIsNotApplicableExplanatoryTextBlock',
#        'WebLinkForGrievanceRedressPolicy',
#        'NumberOfComplaintsFiledFromStakeHolderGroupDuringTheYear',
#        'NumberOfComplaintsPendingFromStakeHolderGroupResolutionAtTheEndOfYear',
#        'RemarksStakeHolderGroupFromWhomComplaintIsReceived',
#        'MaterialIssueIdentified', 'IndicateWhetherRiskOrOpportunity',
#        'RationaleForIdentifyingTheRiskOpportunity',
#        'InCaseOfRiskApproachToAdaptOrMitigate',
#        'FinancialImplicationsOfTheRiskOrOpportunity',
#        'WhetherYourEntitysPolicyOrPoliciesCoverEachPrincipleAndItsCoreElementsOfTheNGRBCs',
#        'HasThePolicyBeenApprovedByTheBoard',
#        'DetailsOfThePolicyIsNotApplicableExplanatoryTextBlock',
#        'WebLinkOfThePoliciesExplanatoryTextBlock',
#        'WhetherTheEntityHasTranslatedThePolicyIntoProcedures',
#        'DetailsOfTheEntityHasNotApplicableTranslatedThePolicyIntoProceduresExplanatoryTextBlock',
#        'DoTheEnlistedPoliciesExtendToYourValueChainPartners',
#        'TheEnlistedPoliciesDoNotApplicableExtendToYourValueChainPartnersExplanatoryTextBlock',
#        'SpecificCommitmentsGoalsAndTargetsSetByTheEntityWithDefinedTimelinesExplanatoryTextBlock',
#        'StatementByDirectorResponsibleForTheBusinessResponsibilityReportHighlightingESGRelatedChallengesTargetsAndAchievementsExplanatoryTextBlock',
#        'DetailsOfTheHighestAuthorityResponsibleForImplementationAndOversightOfTheBusinessResponsibilityPolicyExplanatoryTextBlock',
#        'DoesTheEntityHaveASpecifiedCommitteeOfTheBoardOrDirectorResponsibleForDecisionMakingOnSustainabilityRelatedIssues',
#        'DetailsOfSpecifiedCommitteeOfTheBoardOrDirectorResponsibleForDecisionMakingOnSustainabilityRelatedIssuesExplanatoryTextBlock',
#        'PerformanceAgainstAbovePoliciesAndFollowUpActionIndicateWhetherReviewWasUndertakenBy',
#        'ComplianceWithStatutoryRequirementsOfRelevanceToThePrinciplesAndRectificationOfAnyNonCompliancesIndicateWhetherReviewWasUndertakenBy',
#        'PerformanceAgainstAbovePoliciesAndFollowUpActionFrequency',
#        'ComplianceWithStatutoryRequirementsOfRelevanceToThePrinciplesAndRectificationOfAnyNonCompliancesFrequency',
#        'HasTheEntityCarriedOutIndependentAssessmentEvaluationOfTheWorkingOfItsPoliciesByAnExternalAgency',
#        'TheEntityDoesNotConsiderThePrinciplesMaterialToItsBusiness',
#        'TheEntityIsNotAtAStageWhereItIsInAPositionToFormulateAndImplementThePoliciesOnSpecifiedPrinciples',
#        'TheEntityDoesNotHaveTheFinancialOrHumanAndTechnicalResourcesAvailableForTheTask',
#        'ItIsPlannedToBeDoneInTheNextFinancialYear',
#        'AnyOtherReasonsIfPoliciesNotCoverEachPrincipleAndItsCoreElementsOfTheNGRBCsExplanatoryTextBlock',
#        'TotalNumberOfTrainingAndAwarenessProgramsHeld',
#        'TopicsOrPrinciplesCoveredUnderTheTrainingAndItsImpact',
#        'PercentageOfPersonsInRespectiveCategoryCoveredByTheAwarenessProgrammes',
#        'DoesTheEntityHaveAnAntiCorruptionOrAntiBriberyPolicy',
#        'AntiCorruptionOrAntiBriberyPolicyExplanatoryTextBlock',
#        'WebLinkAtAntiCorruptionOrAntiBriberyPolicyIsPlace',
#        'NumberOfDirectorsAgainstWhomDisciplinaryActionWasTaken',
#        'NumberOfKMPsAgainstWhomDisciplinaryActionWasTaken',
#        'NumberOfEmployeesAgainstWhomDisciplinaryActionWasTaken',
#        'NumberOfWorkersAgainstWhomDisciplinaryActionWasTaken',
#        'NumberOfComplaintsReceivedInRelationToIssuesOfConflictOfInterestOfTheDirectors',
#        'RemarksInCaseComplaintsReceivedInRelationToIssuesOfConflictOfInterestOfTheDirectors',
#        'NumberOfComplaintsReceivedInRelationToIssuesOfConflictOfInterestOfTheKMPs',
#        'RemarksInCaseComplaintsReceivedInRelationToIssuesOfConflictOfInterestOfTheKmps',
#        'DetailsOfAnyCorrectiveActionTakenOrUnderwayOnIssuesRelatedToFinesOrPenaltiesOrActionTakenByRegulatorsOrLawEnforcementAgenciesOrJudicialInstitutionsOnCasesOfCorruptionAndConflictsOfInterestExplanatoryTextBlock',
#        'AmountOfAccountsPayableDuringTheYear',
#        'CostOfGoodsOrServicesProcuredDuringTheYear',
#        'NumberOfDaysOfAccountsPayable',
#        'AmountOfPurchasesFromTradingHouses', 'AmountOfTotalPurchases',
#        'NumberOfTradingHousesWherePurchasesAreMade',
#        'AmountOfPurchasesFromTopTenTradingHouses',
#        'AmountOfTotalPurchasesFromTradingHouses',
#        'AmountOfSalesToDealersOrDistributors', 'AmountOfTotalSales',
#        'NumberOfDealersOrDistributorsToWhomSalesAreMade',
#        'AmountOfSalesToTopTenDealersOrDistributors',
#        'AmountOfTotalSalesToDealersOrDistributors',
#        'AmountOfPurchasesFromRelatedParties',
#        'AmountOfTotalPurchasesForShareOfRelatedPartyTransactions',
#        'AmountOfSalesToRelatedParties',
#        'AmountOfTotalSalesForShareOfRelatedPartyTransactions',
#        'AmountOfLoansAndAdvancesGivenToRelatedParties',
#        'AmountOfTotalLoansAndAdvances',
#        'AmountOfInvestmentsInRelatedParties', 'AmountOfTotalInvestments',
#        'PercentageOfInvestmentsInRelatedPartiesInTotalInvestments',
#        'DoesTheEntityHaveProcessesInPlaceToAvoidOrManageConflictOfInterestsInvolvingMembersOfTheBoard',
#        'DetailsOfTheEntityHaveProcessesInPlaceToAvoidOrManageConflictOfInterestsInvolvingMembersOfTheBoardExplanatoryTextBlock',
#        'NotesPrinciple1ExplanatoryTextBlock', 'PercentageOfRAndD',
#        'DetailsOfImprovementsInEnvironmentalAndSocialImpactsDueToRAndD',
#        'PercentageOfCapex',
#        'DetailsOfImprovementsInEnvironmentalAndSocialImpactsDueToCapex',
#        'DoesTheEntityHaveProceduresInPlaceForSustainableSourcing',
#        'PercentageOfInputsWereSourcedSustainably',
#        'DescribeTheProcessesInPlaceToSafelyReclaimYourProductsForReusingRecyclingAndDisposingAtTheEndOfLifeForPlasticsIncludingPackagingExplanatoryTextBlock',
#        'DescribeTheProcessesInPlaceToSafelyReclaimYourProductsForReusingRecyclingAndDisposingAtTheEndOfLifeForEWasteExplanatoryTextBlock',
#        'DescribeTheProcessesInPlaceToSafelyReclaimYourProductsForReusingRecyclingAndDisposingAtTheEndOfLifeForHazardousWasteExplanatoryTextBlock',
#        'DescribeTheProcessesInPlaceToSafelyReclaimYourProductsForReusingRecyclingAndDisposingAtTheEndOfLifeForOtherWasteExplanatoryTextBlock',
#        'WhetherExtendedProducerResponsibilityIsApplicableToTheEntitySActivities',
#        'HasTheEntityConductedLifeCyclePerspectiveOrAssessmentsForAnyOfItsProductsOrForItsServices',
#        'TheEntityHasNotApplicableConductedLifeCyclePerspectiveOrAssessmentsForAnyOfItsProductsOrForItsServicesExplanatoryTextBlock',
#        'NotesPrinciple2ExplanatoryTextBlock', 'AmountOfReUsed',
#        'AmountOfRecycled', 'AmountOfSafelyDisposed',
#        'NumberOfWellBeingOfEmployeesOrWorkers',
#        'PercentageOfWellBeingOfEmployeesOrWorkers',
#        'AmountOfCostIncurredOnWellBeingMeasures',
#        'TotalRevenueOfTheCompany',
#        'PercentageOfCostIncurredOnWellBeingMeasuresWithRespectToTotalRevenueOfTheCompany',
#        'NumberOfEmployeesCoveredAsPercentageOfTotalEmployees',
#        'NumberOfEmployeesCoveredAsPercentageOfTotalWorker',
#        'DeductedAndDepositedWithTheAuthority',
#        'AreThePremisesOrOfficesOfTheEntityAccessibleToDifferentlyAbledEmployeesAndWorkers',
#        'DoesTheEntityHaveAnEqualOpportunityPolicyAsPerTheRightsOfPersonsWithDisabilitiesAct2016',
#        'WebLinkOfEqualOppertunityPolicyTextBlock',
#        'IsThereAMechanismAvailableToReceiveAndRedressGrievancesForTheFollowingCategoriesOfEmployeesAndWorker',
#        'IsThereAMechanismAvailableToReceiveAndRedressGrievancesForPermanentWorkers',
#        'DetailsOfMechanismAvailableToReceiveAndRedressGrievancesForPermanentWorkersExplanatoryTextBlock',
#        'IsThereAMechanismAvailableToReceiveAndRedressGrievancesForOtherThanPermanentWorkers',
#        'IsThereAMechanismAvailableToReceiveAndRedressGrievancesForPermanentEmployees',
#        'DetailsOfMechanismAvailableToReceiveAndRedressGrievancesForPermanentEmployeesExplanatoryTextBlock',
#        'IsThereAMechanismAvailableToReceiveAndRedressGrievancesForOtherThanPermanentEmployees',
#        'WhetherAnOccupationalHealthAndSafetyManagementSystemHasBeenImplementedByTheEntity',
#        'DetailsOfOccupationalHealthAndSafetyManagementSystemExplanatoryTextBlock',
#        'DesclosureOfTheProcessesUsedToIdentifyWorkRelatedHazardsAndAssessRisksOnARoutineAndNonRoutineBasisByTheEntityExplanatoryTextBlock',
#        'WhetherYouHaveProcessesForWorkersToReportTheWorkRelatedHazardsAndToRemoveThemselvesFromSuchRisks',
#        'DoTheEmployeesOrWorkerOfTheEntityHaveAccessToNonOccupationalMedicalAndHealthcareServices',
#        'DescribeTheMeasuresTakenByTheEntityToEnsureASafeAndHealthyWorkPlaceExplanatoryTextBlock',
#        'DetailsOfAnyCorrectiveActionTakenOrUnderwayToAddressSafetyRelatedIncidentsOfYourPlantsAndOfficesThatWereAssessedExplanatoryTextBlock',
#        'PercentageOfHealthAndSafetyPracticesOfYourPlantsAndOfficesThatWereAssessedP3',
#        'PercentageOfWorkingConditionsOfYourPlantsAndOfficesThatWereAssessedP3',
#        'NotesPrinciple3ExplanatoryTextBlock',
#        'ReturnToWorkRatePermanentEmployeesThatTookParentalLeave',
#        'RetentionRatesPermanentEmployeesThatTookParentalLeave',
#        'ReturnToWorkRatePermanentWorkersThatTookParentalLeave',
#        'RetentionRatesPermanentWorkersThatTookParentalLeave',
#        'TotalNumberOfEmployeesOrWorkersForMembership',
#        'NumberOfEmployeesOrWorkersArePartOfAssociationsOrUnion',
#        'PercentageOfEmployeesOrWorkersArePartOfAssociationsOrUnionOfTotalNumberOfEmployee',
#        'NumberOfTrainedEmployeesOrWorkers',
#        'PercentageOfTrainedEmployeesOrWorkers',
#        'TotalNumberOfEmployeesOrWorkersForPerformanceAndCareerDevelopment',
#        'NumberOfEmployeesOrWorkerForPerformanceAndCareerDevelopment',
#        'PercentageOfEmployeesOrWorkerForPerformanceAndCareerDevelopment',
#        'LostTimeInjuryFrequencyRatePerOneMillionPersonHoursWorked',
#        'TotalRecordableWorkRelatedInjuries', 'NumberOfFatalities',
#        'HighConsequenceWorkRelatedInjuryOrIllHealthExcludingFatalities',
#        'NumberOfComplaintsFiledDuringTheYear',
#        'NumberOfComplaintsPendingResolutionAtTheEndOfYear',
#        'DoesTheEntityExtendAnyLifeInsuranceOrAnyCompensatoryPackageInTheEventOfDeathOfEmployees',
#        'DoesTheEntityExtendAnyLifeInsuranceOrAnyCompensatoryPackageInTheEventOfDeathOfWorkers',
#        'DetailsOfMeasuresUndertakenByTheEntityToEnsureThatStatutoryDuesHaveBeenDeductedAndDepositedByTheValueChainPartnersExplanatoryTextBlock',
#        'TotalNumberOfAffectedEmployees',
#        'NumberOfEmployeesOrWhoseFamilyMembersRehabilitatedAndPlacedInSuitableEmployment',
#        'TotalNumberOfAffectedWorkers',
#        'NumberOfWorkersOrWhoseFamilyMembersRehabilitatedAndPlacedInSuitableEmployment',
#        'DoesTheEntityProvideTransitionAssistanceProgramsToFacilitateContinuedEmployabilityAndTheManagementOfCareerEndingsResultingFromRetirementOrTerminationOfEmployment',
#        'PercentageOfHealthAndSafetyPracticesOfValueChainPartnersP3',
#        'PercentageOfWorkingConditionsOfValueChainPartnersP3',
#        'DetailsOfAnyCorrectiveActionTakenOrUnderwayToAddressSafetyRelatedIncidentsOnAssessmentOfValueChainPartnersExplanatoryTextBlock',
#        'DescribeTheProcessesForIdentifyingKeyStakeholderGroupsOfTheEntityExplanatoryTextBlock',
#        'ProvideTheProcessesForConsultationBetweenStakeholdersAndTheBoardOnEconomicEnvironmentalAndSocialTopicsOrIfConsultationIsDelegatedHowIsFeedbackFromSuchConsultationsProvidedToTheBoardExplanatoryTextBlock',
#        'WhetherStakeholderConsultationIsUsedToSupportTheIdentificationAndManagementOfEnvironmentalAndSocialTopics',
#        'DetailsOfInstancesOfEngagementWithAndActionsTakenToAddressTheConcernsOfVulnerableMarginalizedStakeholderGroupsExplanatoryTextBlock',
#        'StakeholderGroup',
#        'WhetherIdentifiedAsVulnerableAndMarginalizedGroup',
#        'ChannelsOfCommunication', 'DetailsOfOtherChannelsOfCommunication',
#        'FrequencyOfEngagement', 'DetailsOfOtherFrequencyOfEngagement',
#        'PurposeAndScopeOfEngagementIncludingKeyTopicsAndConcernsRaisedDuringSuchEngagement',
#        'TotalNumberOfEmployeesOrWorkersForTrainingOnHumanRightsIssues',
#        'NumberOfEmployeesOrWorkersCoveredForProvidedTrainingOnHumanRightsIssues',
#        'PercentageOfEmployeesOrWorkersCoveredForProvidedTrainingOnHumanRightsIssues',
#        'NumberOfEmployeesOrWorkersRelatedToMinimumWages',
#        'PercentageOfEmployeesOrWorkersRelatedToMinimumWages',
#        'NumberOfBoardOfDirectorsForRemunerationOrSalaryOrWages',
#        'MedianOfRemunerationOrSalaryOrWagesOfBoardOfDirectors',
#        'NumberOfKeyManagerialPersonnelForRemunerationOrSalaryOrWages',
#        'MedianOfRemunerationOrSalaryOrWagesOfKeyManagerialPersonnel',
#        'NumberOfEmployeesOtherThanBodAndKMPForRemunerationOrSalaryOrWages',
#        'MedianOfRemunerationOrSalaryOrWagesOfEmployeesOtherThanBodAndKMP',
#        'NumberOfWorkersForRemunerationOrSalaryOrWages',
#        'MedianOfRemunerationOrSalaryOrWagesOfWorkers',
#        'GrossWagesPaidToFemale', 'TotalWagesPaid',
#        'PercentageOfGrossWagesPaidToFemaleToTotalWagesPaid',
#        'DoYouHaveAFocalPointResponsibleForAddressingHumanRightsImpactsOrIssuesCausedOrContributedToByTheBusiness',
#        'DescribeTheInternalMechanismsInPlaceToRedressGrievancesRelatedToHumanRightsIssuesExplanatoryTextBlock',
#        'TotalComplaintsReportedUnderSexualHarassmentOfWomenAtWorkplace',
#        'AverageNumberOfFemaleEmployeesOrWorkersAtTheBeginningOfTheYearAndAsAtEndOfTheYear',
#        'ComplaintsOnPOSHUpHeld',
#        'MechanismsToPreventAdverseConsequencesToTheComplainantInDiscriminationAndHarassmentCasesExplanatoryTextBlock',
#        'DoHumanRightsRequirementsFormPartOfYourBusinessAgreementsAndContracts',
#        'PercentageOfChildLabourOfYourPlantsAndOfficesThatWereAssessedP5',
#        'PercentageOfForcedLabourOrInvoluntaryLabourOfYourPlantsAndOfficesThatWereAssessedP5',
#        'PercentageOfSexualHarassmentOfYourPlantsAndOfficesThatWereAssessedP5',
#        'PercentageOfDiscriminationAtWorkPlaceOfYourPlantsAndOfficesThatWereAssessedP5',
#        'PercentageOfWagesOfYourPlantsAndOfficesThatWereAssessedP5',
#        'DetailsOfAnyCorrectiveActionsTakenOrUnderwayToAddressSignificantRisksOrConcernsArisingFromTheAssessmentsOfPlantAndOfficeExplanatoryTextBlock',
#        'DetailsOfABusinessProcessBeingModifiedOrIntroducedAsAResultOfAddressingHumanRightsGrievancesOrComplaintsExplanatoryTextBlock',
#        'DetailsOfTheScopeAndCoverageOfAnyHumanRightsDueDiligenceConductedExplanatoryTextBlock',
#        'IsThePremiseOrOfficeOfTheEntityAccessibleToDifferentlyAbledVisitorsAsPerTheRequirementsOfTheRightsOfPersonsWithDisabilitiesAct2016',
#        'PercentageOfSexualHarassmentOfValueChainPartnersP5',
#        'PercentageOfDiscriminationAtWorkPlaceOfValueChainPartnersP5',
#        'PercentageOfChildLabourOfValueChainPartnersP5',
#        'PercentageOfForcedLabourOrInvoluntaryLabourOfValueChainPartnersP5',
#        'PercentageOfWagesOfValueChainPartnersP5',
#        'DetailsOfAnyCorrectiveActionsTakenOrUnderwayToAddressSignificantRisksOrConcernsArisingFromTheAssessmentsOfValueChainPartnerExplanatoryTextBlock',
#        'NotesPrinciple5ExplanatoryTextBlock',
#        'WhetherDetailsOfTotalEnergyConsumptionAndEnergyIntensityApplicableToTheCompany',
#        'RevenueFromOperations',
#        'TotalElectricityConsumptionFromRenewableSources',
#        'TotalFuelConsumptionFromRenewableSources',
#        'EnergyConsumptionThroughOtherSourcesFromRenewableSources',
#        'TotalEnergyConsumedFromRenewableSources',
#        'TotalElectricityConsumptionFromNonRenewableSources',
#        'TotalFuelConsumptionFromNonRenewableSources',
#        'EnergyConsumptionThroughOtherSourcesFromNonRenewableSources',
#        'TotalEnergyConsumedFromNonRenewableSources',
#        'TotalEnergyConsumedFromRenewableAndNonRenewableSources',
#        'EnergyIntensityPerRupeeOfTurnover',
#        'EnergyIntensityPerRupeeOfTurnoverAdjustingForPurchasingPowerParity',
#        'EnergyIntensityInTermOfPhysicalOutput',
#        'EnergyIntensityTheRelevantMetricMayBeSelectedByTheEntity',
#        'WhetherAnyIndependentAssessmentOrEvaluationOrAssuranceHasBeenCarriedOutByAnExternalAgencyForEnergyConsumptionUnderLeadershipIndicators',
#        'DoesTheEntityHaveAnySitesOrFacilitiesIdentifiedAsDesignatedConsumersUnderThePerformanceAchieveAndTradeSchemeOfTheGovernmentOfIndia',
#        'WaterWithdrawalBySurfaceWater', 'WaterWithdrawalByGroundwater',
#        'WaterWithdrawalByThirdPartyWater',
#        'WaterWithdrawalBySeawaterOrDesalinatedWater',
#        'WaterWithdrawalByOthers', 'TotalVolumeOfWaterWithdrawal',
#        'TotalVolumeOfWaterConsumption',
#        'WaterIntensityPerRupeeOfTurnover',
#        'WaterIntensityPerRupeeOfTurnoverAdjustingForPurchasingPowerParity',
#        'WaterIntensityInTermOfPhysicalOutput',
#        'WaterIntensityTheRelevantMetricMayBeSelectedByTheEntity',
#        'AnyIndependentAssessmentOrEvaluationOrAssuranceHasBeenCarriedOutByAnExternalAgencyForWaterWithdrawal',
#        'WaterDischargeToSurfaceWater',
#        'WaterDischargeToSurfaceWaterWithOutTreatment',
#        'WaterDischargeToSurfaceWaterWithTreatment',
#        'WaterDischargeToGroundwater',
#        'WaterDischargeToGroundwaterWithOutTreatment',
#        'WaterDischargeToGroundwaterWithTreatment',
#        'WaterDischargeToSeawater',
#        'WaterDischargeToSeawaterWithOutTreatment',
#        'WaterDischargeToSeawaterWithTreatment',
#        'WaterDischargeBySentToThirdParties',
#        'WaterDischargeBySentToThirdPartiesWithoutTreatment',
#        'WaterDischargeBySentToThirdPartiesWithTreatment',
#        'WaterDischargeToOthers', 'WaterDischargeToOthersWithoutTreatment',
#        'WaterDischargeToOthersWithTreatment',
#        'TotalWaterDischargedInKilolitres',
#        'WhetherAnyIndependentAssessmentOrEvaluationOrAssuranceHasBeenCarriedOutByAnExternalAgencyForWaterDischarged',
#        'HasTheEntityImplementedAMechanismForZeroLiquidDischarge',
#        'AMechanismForZeroLiquidDischargeIsNotApplicableToTheEntityExplanatoryTextBlock',
#        'WhetherDetailsOfAirEmissionsOtherThanGhgEmissionsByTheEntityIsApplicableToTheCompany',
#        'WhetherDetailsOfGreenHouseGasEmissionsAndItsIntensityIsApplicableToTheCompany',
#        'DoesTheEntityHaveAnyProjectRelatedToReducingGreenHouseGasEmission',
#        'ProjectRelatedToReducingGreenHouseGasEmissionIsNotApplicableToTheEntityExplanatoryTextBlock',
#        'PlasticWaste', 'EWaste', 'BioMedicalWaste',
#        'ConstructionAndDemolitionWaste', 'BatteryWaste',
#        'RadioactiveWaste', 'OtherHazardousWaste',
#        'OtherNonHazardousWasteGenerated', 'TotalWasteGenerated',
#        'WasteIntensityPerRupeeOfTurnover',
#        'WasteIntensityPerRupeeOfTurnoverAdjustingForPurchasingPowerParity',
#        'WasteIntensityInTermOfPhysicalOutput',
#        'WasteIntensityTheRelevantMetricMayBeSelectedByTheEntity',
#        'WasteRecoveredThroughRecycled', 'WasteRecoveredThroughReUsed',
#        'WasteRecoveredThroughOtherRecoveryOperations',
#        'TotalWasteRecovered', 'WasteDisposedByIncineration',
#        'WasteDisposedByLandfilling',
#        'WasteDisposedByOtherDisposalOperations', 'TotalWasteDisposed',
#        'WhetherAnyIndependentAssessmentOrEvaluationOrAssuranceHasBeenCarriedOutByAnExternalAgencyForWasteManagement',
#        'DetailsOfWasteManagementPracticesAdoptedInYourEstablishmentsAndTheStrategyAdoptedByCompanyToReduceUsageOfHazardousAndToxicChemicalsExplanatoryTextBlock',
#        'IsTheEntityCompliantWithTheApplicableEnvironmentalLaw',
#        'IndicateIfAnyIndependentAssessmentOrEvaluationOrAssuranceHasBeenCarriedOutByAnExternalAgencyForAreasOfWaterStress',
#        'WhetherTotalScope3EmissionsAndItsIntensityIsApplicableToTheCompany',
#        'DoesTheEntityHaveABusinessContinuityAndDisasterManagementPlan',
#        'DisclosureWebLinkOfEntityAtWhichBusinessContinuityAndDisasterManagementPlanIsPlaced',
#        'DiscloseAnySignificantAdverseImpactToTheEnvironmentArisingFromTheValueChainOfTheEntityWhatMitigationOrAdaptationMeasuresHaveBeenTakenByTheEntityInThisRegardExplanatoryTextBlock',
#        'PercentageOfValueChainPartnersByValueOfBusinessDoneWithSuchPartnersThatWereAssessedForEnvironmentalImpacts',
#        'NotesPrinciple6ExplanatoryTextBlock',
#        'NumberOfAffiliationsWithTradeAndIndustryChambersOrAssociations',
#        'NotesPrinciple7ExplanatoryTextBlock',
#        'NameOfTheTradeAndIndustryChambersOrAssociations',
#        'ReachOfTradeAndIndustryChambersOrAssociations',
#        'DescribeTheMechanismsToReceiveAndRedressGrievancesOfTheCommunityExplanatoryTextBlock',
#        'PercentageOfDirectlySourcedFromMSMEsOrSmallProducers',
#        'PercentageOfSourcedDirectlyFromWithinTheDistrictAndNeighbouringDistricts',
#        'DiscloseWagesPaidToPersonsEmployed', 'TotalWageCost',
#        'PercentageOfJobCreation', 'NotesPrinciple8ExplanatoryTextBlock',
#        'DoYouHaveAPreferentialProcurementPolicyWhereYouGivePreferenceToPurchaseFromSuppliersComprisingMarginalizedOrVulnerableGroups',
#        'FromWhichMarginalizedOrVulnerableGroupsDoYouProcure',
#        'WhatPercentageOfTotalProcurementByValueDoesItConstitute',
#        'DescribeTheMechanismsInPlaceToReceiveAndRespondToConsumerComplaintsAndFeedbackExplanatoryTextBlock',
#        'EnvironmentalAndSocialParametersRelevantToTheProductAsAPercentageToTotalTurnover',
#        'SafeAndResponsibleUsageAsAPercentageToTotalTurnover',
#        'RecyclingAndOrSafeDisposalAsAPercentageToTotalTurnover',
#        'ConsumerComplaintsReceivedDuringTheYear',
#        'ConsumerComplaintsPendingResolutionAtEndOfYear',
#        'RemarkForConsumerComplaints', 'NumberOfVoluntaryRecalls',
#        'ReasonsForVoluntaryRecall', 'NumberOfForcedRecalls',
#        'ReasonsForForcedRecall',
#        'DoesTheEntityHaveAFrameworkOrPolicyOnCyberSecurityAndRisksRelatedToDataPrivacy',
#        'WebLinkOfThePolicyOnCyberSecurityAndRisksRelatedToDataPrivacy',
#        'DetailsOfAnyCorrectiveActionsTakenOrUnderwayOnIssuesRelatingToAdvertisingAndDeliveryOfEssentialServicesOrCyberSecurityAndDataPrivacyOrRecallsOrPenaltyOrActionTakenByRegulatoryAuthoritiesOnSafetyOfProductsOrServicesExplanatoryTextBlock',
#        'NumberOfInstancesOfDataBreachesAlongWithImpact',
#        'PercentageOfDataBreachesInvolvingPersonallyIdentifiableInformationOfCustomers',
#        'DetailsOfImpactOfDataBreachesExplanatoryTextBlock',
#        'WeblinkWhereInformationOnProductsAndServicesOfTheEntityCanBeAccessedExplanatoryTextBlock',
#        'StepsTakenToInformAndEducateConsumersAboutSafeAndResponsibleUsageOfProductsAndOrServicesExplanatoryTextBlock',
#        'MechanismsInPlaceToInformConsumersOfAnyRiskOfDisruptionOrDiscontinuationOfEssentialServicesExplanatoryTextBlock',
#        'DoesTheEntityDisplayProductInformationOnTheProductOverAndAboveWhatIsMandatedAsPerLocalLaws',
#        'DetailsOfProductInformationOnTheProductOverAndAboveWhatIsMandatedAsPerLocalLawsExplanatoryTextBlock',
#        'DidYourEntityCarryOutAnySurveyWithRegardToConsumerSatisfactionRelatingToTheMajorProductsOrServicesOfTheEntitySignificantLocationsOfOperationOfTheEntityOrTheEntityAsAWhole',
#        'TheEntityHasNotApplicableCarryOutAnySurveyWithRegardToConsumerSatisfactionRelatingToTheMajorProductsOrServicesExplanatoryTextBlock'],
#       dtype=object)

# %%
df['Period/Context'].unique()
# Out:
# array(['DCYMain', 'ICYMain', 'D_StockExchangeAxis1',
#        'D_StockExchangeAxis2', 'D_BusinessActivities1',
#        'D_ProductServiceSold1', 'D_Plant_National', 'D_Office_National',
#        'D_Location_National', 'D_Plant_International',
#        'D_Office_International', 'D_Location_International',
#        'D_Gender_PermanentEmployees_TableA',
#        'D_Male_PermanentEmployees_TableA',
#        'D_Female_PermanentEmployees_TableA',
#        'D_OtherGender_PermanentEmployees_TableA',
#        'D_Gender_OtherThanPermanentEmployees_TableA',
#        'D_Male_OtherThanPermanentEmployees_TableA',
#        'D_Female_OtherThanPermanentEmployees_TableA',
#        'D_OtherGender_OtherThanPermanentEmployees_TableA',
#        'D_Gender_Employees_TableA', 'D_Male_Employees_TableA',
#        'D_Female_Employees_TableA', 'D_OtherGender_Employees_TableA',
#        'D_Gender_PermanentWorkers_TableA',
#        'D_Male_PermanentWorkers_TableA',
#        'D_Female_PermanentWorkers_TableA',
#        'D_OtherGender_PermanentWorkers_TableA',
#        'D_Gender_OtherThanPermanentWorkers_TableA',
#        'D_Male_OtherThanPermanentWorkers_TableA',
#        'D_Female_OtherThanPermanentWorkers_TableA',
#        'D_OtherGender_OtherThanPermanentWorkers_TableA',
#        'D_Gender_Workers_TableA', 'D_Male_Workers_TableA',
#        'D_Female_Workers_TableA', 'D_OtherGender_Workers_TableA',
#        'D_Gender_PermanentEmployees_TableB',
#        'D_Male_PermanentEmployees_TableB',
#        'D_Female_PermanentEmployees_TableB',
#        'D_OtherGender_PermanentEmployees_TableB',
#        'D_Gender_OtherThanPermanentEmployees_TableB',
#        'D_Male_OtherThanPermanentEmployees_TableB',
#        'D_Female_OtherThanPermanentEmployees_TableB',
#        'D_OtherGender_OtherThanPermanentEmployees_TableB',
#        'D_Gender_Employees_TableB', 'D_Male_Employees_TableB',
#        'D_Female_Employees_TableB', 'D_OtherGender_Employees_TableB',
#        'D_Gender_PermanentWorkers_TableB',
#        'D_Male_PermanentWorkers_TableB',
#        'D_Female_PermanentWorkers_TableB',
#        'D_OtherGender_PermanentWorkers_TableB',
#        'D_Gender_OtherThanPermanentWorkers_TableB',
#        'D_Male_OtherThanPermanentWorkers_TableB',
#        'D_Female_OtherThanPermanentWorkers_TableB',
#        'D_OtherGender_OtherThanPermanentWorkers_TableB',
#        'D_Gender_Workers_TableB', 'D_Male_Workers_TableB',
#        'D_Female_Workers_TableB', 'D_OtherGender_Workers_TableB',
#        'D_Male_PermanentEmployees_TableB_TurnOverRate_CY',
#        'D_Female_PermanentEmployees_TableB_TurnOverRate_CY',
#        'D_OtherGender_PermanentEmployees_TableB_TurnOverRate_CY',
#        'D_Gender_PermanentEmployees_TableB_TurnOverRate_CY',
#        'D_Male_PermanentEmployees_TableB_TurnOverRate_PY',
#        'D_Female_PermanentEmployees_TableB_TurnOverRate_PY',
#        'D_OtherGender_PermanentEmployees_TableB_TurnOverRate_PY',
#        'D_Gender_PermanentEmployees_TableB_TurnOverRate_PY',
#        'D_Male_PermanentEmployees_TableB_TurnOverRate_PPY',
#        'D_Female_PermanentEmployees_TableB_TurnOverRate_PPY',
#        'D_OtherGender_PermanentEmployees_TableB_TurnOverRate_PPY',
#        'D_Gender_PermanentEmployees_TableB_TurnOverRate_PPY',
#        'D_Male_PermanentWorkers_TableB_TurnOverRate_CY',
#        'D_Female_PermanentWorkers_TableB_TurnOverRate_CY',
#        'D_OtherGender_PermanentWorkers_TableB_TurnOverRate_CY',
#        'D_Gender_PermanentWorkers_TableB_TurnOverRate_CY',
#        'D_Male_PermanentWorkers_TableB_TurnOverRate_PY',
#        'D_Female_PermanentWorkers_TableB_TurnOverRate_PY',
#        'D_OtherGender_PermanentWorkers_TableB_TurnOverRate_PY',
#        'D_Gender_PermanentWorkers_TableB_TurnOverRate_PY',
#        'D_Male_PermanentWorkers_TableB_TurnOverRate_PPY',
#        'D_Female_PermanentWorkers_TableB_TurnOverRate_PPY',
#        'D_OtherGender_PermanentWorkers_TableB_TurnOverRate_PPY',
#        'D_Gender_PermanentWorkers_TableB_TurnOverRate_PPY',
#        'D_HoldingSubsidiaryAssociateCompaniesAndJointVentures1',
#        'D_HoldingSubsidiaryAssociateCompaniesAndJointVentures2',
#        'D_HoldingSubsidiaryAssociateCompaniesAndJointVentures3',
#        'D_HoldingSubsidiaryAssociateCompaniesAndJointVentures4',
#        'D_HoldingSubsidiaryAssociateCompaniesAndJointVentures5',
#        'D_HoldingSubsidiaryAssociateCompaniesAndJointVentures6',
#        'D_HoldingSubsidiaryAssociateCompaniesAndJointVentures7',
#        'D_HoldingSubsidiaryAssociateCompaniesAndJointVentures8',
#        'D_HoldingSubsidiaryAssociateCompaniesAndJointVentures9',
#        'D_HoldingSubsidiaryAssociateCompaniesAndJointVentures10',
#        'D_HoldingSubsidiaryAssociateCompaniesAndJointVentures11',
#        'D_HoldingSubsidiaryAssociateCompaniesAndJointVentures12',
#        'D_HoldingSubsidiaryAssociateCompaniesAndJointVentures13',
#        'D_HoldingSubsidiaryAssociateCompaniesAndJointVentures14',
#        'D_ComplaintReceivedFromCommunities',
#        'D_ComplaintReceivedFromInvestors',
#        'I_ComplaintReceivedFromInvestors',
#        'D_ComplaintReceivedFromInvestors_PY',
#        'I_ComplaintReceivedFromInvestors_PY',
#        'D_ComplaintReceivedFromShareholders',
#        'I_ComplaintReceivedFromShareholders',
#        'D_ComplaintReceivedFromShareholders_PY',
#        'I_ComplaintReceivedFromShareholders_PY',
#        'D_ComplaintReceivedFromEmployeesAndWorkers',
#        'I_ComplaintReceivedFromEmployeesAndWorkers',
#        'D_ComplaintReceivedFromEmployeesAndWorkers_PY',
#        'I_ComplaintReceivedFromEmployeesAndWorkers_PY',
#        'D_ComplaintReceivedFromCustomers',
#        'I_ComplaintReceivedFromCustomers',
#        'D_ComplaintReceivedFromCustomers_PY',
#        'I_ComplaintReceivedFromCustomers_PY',
#        'D_ComplaintReceivedFromValueChainPartners',
#        'D_EntitysMaterialResponsibleBusinessConductIssues1',
#        'D_EntitysMaterialResponsibleBusinessConductIssues2',
#        'D_EntitysMaterialResponsibleBusinessConductIssues3',
#        'D_EntitysMaterialResponsibleBusinessConductIssues4',
#        'D_EntitysMaterialResponsibleBusinessConductIssues5',
#        'D_EntitysMaterialResponsibleBusinessConductIssues6',
#        'D_EntitysMaterialResponsibleBusinessConductIssues7',
#        'D_Principle1', 'D_Principle2', 'D_Principle3', 'D_Principle4',
#        'D_Principle5', 'D_Principle6', 'D_Principle7', 'D_Principle8',
#        'D_Principle9', 'D_BoardOfDirectorsSegment',
#        'D_KeyManagerialPersonnelSegment',
#        'D_EmployeesOtherThanBoDAndKMPsSegment', 'D_WorkersSegment',
#        'DPYMain', 'D_PlasticsIncludingPackaging',
#        'D_PlasticsIncludingPackaging_PY', 'D_EWaste', 'D_EWaste_PY',
#        'D_HazardousWaste', 'D_HazardousWaste_PY',
#        'D_Male_TotalEmployeeBenefits_PermanentEmployees_Table1A',
#        'D_Male_HealthInsurance_PermanentEmployees_Table1A',
#        'D_Male_AccidentInsurance_PermanentEmployees_Table1A',
#        'D_Male_PaternityBenefits_PermanentEmployees_Table1A',
#        'D_Male_DayCareFacilities_PermanentEmployees_Table1A',
#        'D_Female_TotalEmployeeBenefits_PermanentEmployees_Table1A',
#        'D_Female_HealthInsurance_PermanentEmployees_Table1A',
#        'D_Female_AccidentInsurance_PermanentEmployees_Table1A',
#        'D_Female_MaternityBenefits_PermanentEmployees_Table1A',
#        'D_Female_DayCareFacilities_PermanentEmployees_Table1A',
#        'D_OtherGender_TotalEmployeeBenefits_PermanentEmployees_Table1A',
#        'D_OtherGender_HealthInsurance_PermanentEmployees_Table1A',
#        'D_OtherGender_AccidentInsurance_PermanentEmployees_Table1A',
#        'D_OtherGender_MaternityBenefits_PermanentEmployees_Table1A',
#        'D_OtherGender_PaternityBenefits_PermanentEmployees_Table1A',
#        'D_OtherGender_DayCareFacilities_PermanentEmployees_Table1A',
#        'D_Gender_Benefits_PermanentEmployees_Table1A',
#        'D_Gender_HealthInsurance_PermanentEmployees_Table1A',
#        'D_Gender_AccidentInsurance_PermanentEmployees_Table1A',
#        'D_Gender_MaternityBenefits_PermanentEmployees_Table1A',
#        'D_Gender_PaternityBenefits_PermanentEmployees_Table1A',
#        'D_Gender_DayCareFacilities_PermanentEmployees_Table1A',
#        'D_Male_TotalEmployeeBenefits_OtherThanPermanentEmployees_Table1A',
#        'D_Male_HealthInsurance_OtherThanPermanentEmployees_Table1A',
#        'D_Male_AccidentInsurance_OtherThanPermanentEmployees_Table1A',
#        'D_Male_PaternityBenefits_OtherThanPermanentEmployees_Table1A',
#        'D_Male_DayCareFacilities_OtherThanPermanentEmployees_Table1A',
#        'D_Female_TotalEmployeeBenefits_OtherThanPermanentEmployees_Table1A',
#        'D_Female_HealthInsurance_OtherThanPermanentEmployees_Table1A',
#        'D_Female_AccidentInsurance_OtherThanPermanentEmployees_Table1A',
#        'D_Female_MaternityBenefits_OtherThanPermanentEmployees_Table1A',
#        'D_Female_DayCareFacilities_OtherThanPermanentEmployees_Table1A',
#        'D_OtherGender_TotalEmployeeBenefits_OtherThanPermanentEmployees_Table1A',
#        'D_OtherGender_HealthInsurance_OtherThanPermanentEmployees_Table1A',
#        'D_OtherGender_AccidentInsurance_OtherThanPermanentEmployees_Table1A',
#        'D_OtherGender_MaternityBenefits_OtherThanPermanentEmployees_Table1A',
#        'D_OtherGender_PaternityBenefits_OtherThanPermanentEmployees_Table1A',
#        'D_OtherGender_DayCareFacilities_OtherThanPermanentEmployees_Table1A',
#        'D_Gender_Benefits_OtherThanPermanentEmployees_Table1A',
#        'D_Gender_HealthInsurance_OtherThanPermanentEmployees_Table1A',
#        'D_Gender_AccidentInsurance_OtherThanPermanentEmployees_Table1A',
#        'D_Gender_MaternityBenefits_OtherThanPermanentEmployees_Table1A',
#        'D_Gender_PaternityBenefits_OtherThanPermanentEmployees_Table1A',
#        'D_Gender_DayCareFacilities_OtherThanPermanentEmployees_Table1A',
#        'D_Male_TotalEmployeeBenefits_PermanentWorkers_Table1B',
#        'D_Male_HealthInsurance_PermanentWorkers_Table1B',
#        'D_Male_AccidentInsurance_PermanentWorkers_Table1B',
#        'D_Male_PaternityBenefits_PermanentWorkers_Table1B',
#        'D_Male_DayCareFacilities_PermanentWorkers_Table1B',
#        'D_Female_TotalEmployeeBenefits_PermanentWorkers_Table1B',
#        'D_Female_HealthInsurance_PermanentWorkers_Table1B',
#        'D_Female_AccidentInsurance_PermanentWorkers_Table1B',
#        'D_Female_MaternityBenefits_PermanentWorkers_Table1B',
#        'D_Female_DayCareFacilities_PermanentWorkers_Table1B',
#        'D_OtherGender_TotalEmployeeBenefits_PermanentWorkers_Table1B',
#        'D_OtherGender_HealthInsurance_PermanentWorkers_Table1B',
#        'D_OtherGender_AccidentInsurance_PermanentWorkers_Table1B',
#        'D_OtherGender_MaternityBenefits_PermanentWorkers_Table1B',
#        'D_OtherGender_PaternityBenefits_PermanentWorkers_Table1B',
#        'D_OtherGender_DayCareFacilities_PermanentWorkers_Table1B',
#        'D_Gender_Benefits_PermanentWorkers_Table1B',
#        'D_Gender_HealthInsurance_PermanentWorkers_Table1B',
#        'D_Gender_AccidentInsurance_PermanentWorkers_Table1B',
#        'D_Gender_MaternityBenefits_PermanentWorkers_Table1B',
#        'D_Gender_PaternityBenefits_PermanentWorkers_Table1B',
#        'D_Gender_DayCareFacilities_PermanentWorkers_Table1B',
#        'D_Male_TotalEmployeeBenefits_OtherThanPermanentWorkers_Table1B',
#        'D_Male_HealthInsurance_OtherThanPermanentWorkers_Table1B',
#        'D_Male_AccidentInsurance_OtherThanPermanentWorkers_Table1B',
#        'D_Male_PaternityBenefits_OtherThanPermanentWorkers_Table1B',
#        'D_Male_DayCareFacilities_OtherThanPermanentWorkers_Table1B',
#        'D_Female_TotalEmployeeBenefits_OtherThanPermanentWorkers_Table1B',
#        'D_Female_HealthInsurance_OtherThanPermanentWorkers_Table1B',
#        'D_Female_AccidentInsurance_OtherThanPermanentWorkers_Table1B',
#        'D_Female_MaternityBenefits_OtherThanPermanentWorkers_Table1B',
#        'D_Female_DayCareFacilities_OtherThanPermanentWorkers_Table1B',
#        'D_OtherGender_TotalEmployeeBenefits_OtherThanPermanentWorkers_Table1B',
#        'D_OtherGender_HealthInsurance_OtherThanPermanentWorkers_Table1B',
#        'D_OtherGender_AccidentInsurance_OtherThanPermanentWorkers_Table1B',
#        'D_OtherGender_MaternityBenefits_OtherThanPermanentWorkers_Table1B',
#        'D_OtherGender_PaternityBenefits_OtherThanPermanentWorkers_Table1B',
#        'D_OtherGender_DayCareFacilities_OtherThanPermanentWorkers_Table1B',
#        'D_Gender_Benefits_OtherThanPermanentWorkers_Table1B',
#        'D_Gender_HealthInsurance_OtherThanPermanentWorkers_Table1B',
#        'D_Gender_AccidentInsurance_OtherThanPermanentWorkers_Table1B',
#        'D_Gender_MaternityBenefits_OtherThanPermanentWorkers_Table1B',
#        'D_Gender_PaternityBenefits_OtherThanPermanentWorkers_Table1B',
#        'D_Gender_DayCareFacilities_OtherThanPermanentWorkers_Table1B',
#        'D_ProvidentFund', 'D_ProvidentFund_PY', 'D_Gratuity',
#        'D_Gratuity_PY', 'D_ESI', 'D_ESI_PY', 'D_Male', 'D_Female',
#        'D_OtherGender', 'D_Gender', 'D_Gender_PermanentEmployees',
#        'D_Gender_PermanentEmployees_PY', 'D_Male_PermanentEmployees',
#        'D_Male_PermanentEmployees_PY', 'D_Female_PermanentEmployees',
#        'D_Female_PermanentEmployees_PY',
#        'D_OtherGender_PermanentEmployees',
#        'D_OtherGender_PermanentEmployees_PY', 'D_Gender_PermanentWorkers',
#        'D_Gender_PermanentWorkers_PY', 'D_Male_PermanentWorkers',
#        'D_Male_PermanentWorkers_PY', 'D_Female_PermanentWorkers',
#        'D_Female_PermanentWorkers_PY', 'D_OtherGender_PermanentWorkers',
#        'D_OtherGender_PermanentWorkers_PY',
#        'D_Male_TotalEmployeesAndWorkers_Employees',
#        'D_Male_OnHealthAndSafetyMeasures_Employees',
#        'D_Male_OnSkillUpgradation_Employees',
#        'D_Male_TotalEmployeesAndWorkers_Employees_PY',
#        'D_Male_OnHealthAndSafetyMeasures_Employees_PY',
#        'D_Male_OnSkillUpgradation_Employees_PY',
#        'D_Female_TotalEmployeesAndWorkers_Employees',
#        'D_Female_OnHealthAndSafetyMeasures_Employees',
#        'D_Female_OnSkillUpgradation_Employees',
#        'D_Female_TotalEmployeesAndWorkers_Employees_PY',
#        'D_Female_OnHealthAndSafetyMeasures_Employees_PY',
#        'D_Female_OnSkillUpgradation_Employees_PY',
#        'D_OtherGender_TotalEmployeesAndWorkers_Employees',
#        'D_OtherGender_OnHealthAndSafetyMeasures_Employees',
#        'D_OtherGender_OnSkillUpgradation_Employees',
#        'D_OtherGender_TotalEmployeesAndWorkers_Employees_PY',
#        'D_OtherGender_OnHealthAndSafetyMeasures_Employees_PY',
#        'D_OtherGender_OnSkillUpgradation_Employees_PY',
#        'D_Gender_TotalEmployeesAndWorkers_Employees',
#        'D_Gender_OnHealthAndSafetyMeasures_Employees',
#        'D_Gender_OnSkillUpgradation_Employees',
#        'D_Gender_TotalEmployeesAndWorkers_Employees_PY',
#        'D_Gender_OnHealthAndSafetyMeasures_Employees_PY',
#        'D_Gender_OnSkillUpgradation_Employees_PY',
#        'D_Male_TotalEmployeesAndWorkers_Workers',
#        'D_Male_OnHealthAndSafetyMeasures_Workers',
#        'D_Male_OnSkillUpgradation_Workers',
#        'D_Male_TotalEmployeesAndWorkers_Workers_PY',
#        'D_Male_OnHealthAndSafetyMeasures_Workers_PY',
#        'D_Male_OnSkillUpgradation_Workers_PY',
#        'D_Female_TotalEmployeesAndWorkers_Workers',
#        'D_Female_OnHealthAndSafetyMeasures_Workers',
#        'D_Female_OnSkillUpgradation_Workers',
#        'D_Female_TotalEmployeesAndWorkers_Workers_PY',
#        'D_Female_OnHealthAndSafetyMeasures_Workers_PY',
#        'D_Female_OnSkillUpgradation_Workers_PY',
#        'D_OtherGender_TotalEmployeesAndWorkers_Workers',
#        'D_OtherGender_OnHealthAndSafetyMeasures_Workers',
#        'D_OtherGender_OnSkillUpgradation_Workers',
#        'D_OtherGender_TotalEmployeesAndWorkers_Workers_PY',
#        'D_OtherGender_OnHealthAndSafetyMeasures_Workers_PY',
#        'D_OtherGender_OnSkillUpgradation_Workers_PY',
#        'D_Gender_TotalEmployeesAndWorkers_Workers',
#        'D_Gender_OnHealthAndSafetyMeasures_Workers',
#        'D_Gender_OnSkillUpgradation_Workers',
#        'D_Gender_TotalEmployeesAndWorkers_Workers_PY',
#        'D_Gender_OnHealthAndSafetyMeasures_Workers_PY',
#        'D_Gender_OnSkillUpgradation_Workers_PY', 'D_Male_Employees',
#        'D_Male_Employees_PY', 'D_Female_Employees',
#        'D_Female_Employees_PY', 'D_OtherGender_Employees',
#        'D_OtherGender_Employees_PY', 'D_Gender_Employees',
#        'D_Gender_Employees_PY', 'D_Male_Workers', 'D_Male_Workers_PY',
#        'D_Female_Workers', 'D_Female_Workers_PY', 'D_OtherGender_Workers',
#        'D_OtherGender_Workers_PY', 'D_Gender_Workers',
#        'D_Gender_Workers_PY', 'D_Employees', 'D_Employees_PY',
#        'D_Workers', 'D_Workers_PY', 'D_WorkingConditionsComplaints',
#        'I_WorkingConditionsComplaints',
#        'D_WorkingConditionsComplaints_PY',
#        'I_WorkingConditionsComplaints_PY', 'D_HealthSafetyComplaints',
#        'I_HealthSafetyComplaints', 'D_HealthSafetyComplaints_PY',
#        'I_HealthSafetyComplaints_PY', 'D_StakeHolderGroups1',
#        'D_StakeHolderGroups2', 'D_StakeHolderGroups3',
#        'D_StakeHolderGroups4', 'D_StakeHolderGroups5',
#        'D_StakeHolderGroups6', 'D_StakeHolderGroups7',
#        'D_PermanentEmployees_p5', 'D_OtherThanPermanentEmployees_p5',
#        'D_Employees_p5', 'D_PermanentEmployees_p5_PY',
#        'D_OtherThanPermanentEmployees_p5_PY', 'D_Employees_p5_PY',
#        'D_PermanentWorkers_p5', 'D_OtherThanPermanentWorkers_p5',
#        'D_Workers_p5', 'D_PermanentWorkers_p5_PY',
#        'D_OtherThanPermanentWorkers_p5_PY', 'D_Workers_p5_PY',
#        'D_Total_1', 'D_Total_2', 'D_Total_3', 'D_Total_4',
#        'D_EqualToMinimumWage_1', 'D_EqualToMinimumWage_2',
#        'D_EqualToMinimumWage_3', 'D_EqualToMinimumWage_4',
#        'D_MoreThanMinimumWage_1', 'D_MoreThanMinimumWage_2',
#        'D_MoreThanMinimumWage_3', 'D_MoreThanMinimumWage_4',
#        'D_Total_1_PY', 'D_Total_2_PY', 'D_Total_3_PY', 'D_Total_4_PY',
#        'D_EqualToMinimumWage_1_PY', 'D_MoreThanMinimumWage_1_PY',
#        'D_EqualToMinimumWage_2_PY', 'D_MoreThanMinimumWage_2_PY',
#        'D_EqualToMinimumWage_3_PY', 'D_MoreThanMinimumWage_3_PY',
#        'D_EqualToMinimumWage_4_PY', 'D_MoreThanMinimumWage_4_PY',
#        'D_Total_Other_1', 'D_Total_Other_2', 'D_Total_Other_3',
#        'D_Total_Other_4', 'D_EqualToMinimumWage_Other_1',
#        'D_EqualToMinimumWage_Other_2', 'D_EqualToMinimumWage_Other_3',
#        'D_EqualToMinimumWage_Other_4', 'D_MoreThanMinimumWage_Other_1',
#        'D_MoreThanMinimumWage_Other_2', 'D_MoreThanMinimumWage_Other_3',
#        'D_MoreThanMinimumWage_Other_4', 'D_Total_Other_1_PY',
#        'D_Total_Other_2_PY', 'D_Total_Other_3_PY', 'D_Total_Other_4_PY',
#        'D_EqualToMinimumWage_Other_1_PY',
#        'D_MoreThanMinimumWage_Other_1_PY',
#        'D_EqualToMinimumWage_Other_2_PY',
#        'D_MoreThanMinimumWage_Other_2_PY',
#        'D_EqualToMinimumWage_Other_3_PY',
#        'D_MoreThanMinimumWage_Other_3_PY',
#        'D_EqualToMinimumWage_Other_4_PY',
#        'D_MoreThanMinimumWage_Other_4_PY', 'D_Total_W_1', 'D_Total_W_2',
#        'D_Total_W_3', 'D_Total_W_4', 'D_EqualToMinimumWage_W_1',
#        'D_EqualToMinimumWage_W_2', 'D_EqualToMinimumWage_W_3',
#        'D_EqualToMinimumWage_W_4', 'D_MoreThanMinimumWage_W_1',
#        'D_MoreThanMinimumWage_W_2', 'D_MoreThanMinimumWage_W_3',
#        'D_MoreThanMinimumWage_W_4', 'D_Total_W_1_PY', 'D_Total_W_2_PY',
#        'D_Total_W_3_PY', 'D_Total_W_4_PY', 'D_EqualToMinimumWage_W_1_PY',
#        'D_MoreThanMinimumWage_W_1_PY', 'D_EqualToMinimumWage_W_2_PY',
#        'D_MoreThanMinimumWage_W_2_PY', 'D_EqualToMinimumWage_W_3_PY',
#        'D_MoreThanMinimumWage_W_3_PY', 'D_EqualToMinimumWage_W_4_PY',
#        'D_MoreThanMinimumWage_W_4_PY', 'D_Total_Other_W_1',
#        'D_Total_Other_W_2', 'D_Total_Other_W_3', 'D_Total_Other_W_4',
#        'D_EqualToMinimumWage_Other_W_1', 'D_EqualToMinimumWage_Other_W_2',
#        'D_EqualToMinimumWage_Other_W_3', 'D_EqualToMinimumWage_Other_W_4',
#        'D_MoreThanMinimumWage_Other_W_1',
#        'D_MoreThanMinimumWage_Other_W_2',
#        'D_MoreThanMinimumWage_Other_W_3',
#        'D_MoreThanMinimumWage_Other_W_4', 'D_Total_Other_W_1_PY',
#        'D_Total_Other_W_2_PY', 'D_Total_Other_W_3_PY',
#        'D_Total_Other_W_4_PY', 'D_EqualToMinimumWage_Other_W_1_PY',
#        'D_MoreThanMinimumWage_Other_W_1_PY',
#        'D_EqualToMinimumWage_Other_W_2_PY',
#        'D_MoreThanMinimumWage_Other_W_2_PY',
#        'D_EqualToMinimumWage_Other_W_3_PY',
#        'D_MoreThanMinimumWage_Other_W_3_PY',
#        'D_EqualToMinimumWage_Other_W_4_PY',
#        'D_MoreThanMinimumWage_Other_W_4_PY', 'D_Male_p5', 'D_Female_p5',
#        'D_OtherGender_p5', 'D_NumberOfComplaintsFiledDuringTheYear_1',
#        'I_NumberOfComplaintsPendingResolutionAtTheEndOfYear_1',
#        'D_NumberOfComplaintsFiledDuringTheYear_2',
#        'I_NumberOfComplaintsPendingResolutionAtTheEndOfYear_2',
#        'D_NumberOfComplaintsFiledDuringTheYear_3',
#        'I_NumberOfComplaintsPendingResolutionAtTheEndOfYear_3',
#        'D_NumberOfComplaintsFiledDuringTheYear_4',
#        'I_NumberOfComplaintsPendingResolutionAtTheEndOfYear_4',
#        'D_NumberOfComplaintsFiledDuringTheYear_5',
#        'I_NumberOfComplaintsPendingResolutionAtTheEndOfYear_5',
#        'D_NumberOfComplaintsFiledDuringTheYear_6',
#        'I_NumberOfComplaintsPendingResolutionAtTheEndOfYear_6',
#        'D_NumberOfComplaintsFiledDuringTheYear_1_PY',
#        'I_NumberOfComplaintsPendingResolutionAtTheEndOfYear_1_PY',
#        'D_NumberOfComplaintsFiledDuringTheYear_2_PY',
#        'I_NumberOfComplaintsPendingResolutionAtTheEndOfYear_2_PY',
#        'D_NumberOfComplaintsFiledDuringTheYear_3_PY',
#        'I_NumberOfComplaintsPendingResolutionAtTheEndOfYear_3_PY',
#        'D_NumberOfComplaintsFiledDuringTheYear_4_PY',
#        'I_NumberOfComplaintsPendingResolutionAtTheEndOfYear_4_PY',
#        'D_NumberOfComplaintsFiledDuringTheYear_5_PY',
#        'I_NumberOfComplaintsPendingResolutionAtTheEndOfYear_5_PY',
#        'D_NumberOfComplaintsFiledDuringTheYear_6_PY',
#        'I_NumberOfComplaintsPendingResolutionAtTheEndOfYear_6_PY',
#        'D_IndustryChambersOrAssociations1',
#        'D_IndustryChambersOrAssociations2', 'D_Rural', 'D_Rural_PY',
#        'D_SemiUrban', 'D_SemiUrban_PY', 'D_Urban', 'D_Urban_PY',
#        'D_Metropolitan', 'D_Metropolitan_PY', 'D_DataPrivacy',
#        'I_DataPrivacy', 'D_Advertising', 'I_Advertising',
#        'D_CyberSecurity', 'I_CyberSecurity',
#        'D_DeliveryOfEssentialServices', 'I_DeliveryOfEssentialServices',
#        'D_RestrictiveTradePractices', 'I_RestrictiveTradePractices',
#        'D_UnfairTradePractices', 'I_UnfairTradePractices', 'D_Other',
#        'I_Other', 'D_DataPrivacy_PY', 'I_DataPrivacy_PY',
#        'D_Advertising_PY', 'I_Advertising_PY', 'D_CyberSecurity_PY',
#        'I_CyberSecurity_PY', 'D_DeliveryOfEssentialServices_PY',
#        'I_DeliveryOfEssentialServices_PY',
#        'D_RestrictiveTradePractices_PY', 'I_RestrictiveTradePractices_PY',
#        'D_UnfairTradePractices_PY', 'I_UnfairTradePractices_PY',
#        'D_Other_PY', 'I_Other_PY'], dtype=object)

# %%
### 1. Filter to values for "Employees and workers (including differently abled)" table
df[df['Element Name'] == 'NumberOfEmployeesOrWorkersIncludingDifferentlyAbled']
# Out:
#                                          Element Name  \
# 39  NumberOfEmployeesOrWorkersIncludingDifferently...
# 40  NumberOfEmployeesOrWorkersIncludingDifferently...
# 42  NumberOfEmployeesOrWorkersIncludingDifferently...
# 44  NumberOfEmployeesOrWorkersIncludingDifferently...
# 46  NumberOfEmployeesOrWorkersIncludingDifferently...
# 47  NumberOfEmployeesOrWorkersIncludingDifferently...
# 49  NumberOfEmployeesOrWorkersIncludingDifferently...
# 51  NumberOfEmployeesOrWorkersIncludingDifferently...
# 53  NumberOfEmployeesOrWorkersIncludingDifferently...
# 54  NumberOfEmployeesOrWorkersIncludingDifferently...
# 56  NumberOfEmployeesOrWorkersIncludingDifferently...
# 58  NumberOfEmployeesOrWorkersIncludingDifferently...
# 60  NumberOfEmployeesOrWorkersIncludingDifferently...
# 61  NumberOfEmployeesOrWorkersIncludingDifferently...
# 63  NumberOfEmployeesOrWorkersIncludingDifferently...
# 65  NumberOfEmployeesOrWorkersIncludingDifferently...
# 67  NumberOfEmployeesOrWorkersIncludingDifferently...
# 68  NumberOfEmployeesOrWorkersIncludingDifferently...
# 70  NumberOfEmployeesOrWorkersIncludingDifferently...
# 72  NumberOfEmployeesOrWorkersIncludingDifferently...
# 74  NumberOfEmployeesOrWorkersIncludingDifferently...
# 75  NumberOfEmployeesOrWorkersIncludingDifferently...
# 77  NumberOfEmployeesOrWorkersIncludingDifferently...
# 79  NumberOfEmployeesOrWorkersIncludingDifferently...
#
#                                       Period/Context  Unit Decimals Value
# 39                D_Gender_PermanentEmployees_TableA  pure        0   116
# 40                  D_Male_PermanentEmployees_TableA  pure        0    77
# 42                D_Female_PermanentEmployees_TableA  pure        0    39
# 44           D_OtherGender_PermanentEmployees_TableA  pure        0     0
# 46       D_Gender_OtherThanPermanentEmployees_TableA  pure        0    23
# 47         D_Male_OtherThanPermanentEmployees_TableA  pure        0    19
# 49       D_Female_OtherThanPermanentEmployees_TableA  pure        0     4
# 51  D_OtherGender_OtherThanPermanentEmployees_TableA  pure        0     0
# 53                         D_Gender_Employees_TableA  pure        0   139
# 54                           D_Male_Employees_TableA  pure        0    96
# 56                         D_Female_Employees_TableA  pure        0    43
# 58                    D_OtherGender_Employees_TableA  pure        0     0
# 60                  D_Gender_PermanentWorkers_TableA  pure        0     1
# 61                    D_Male_PermanentWorkers_TableA  pure        0     1
# 63                  D_Female_PermanentWorkers_TableA  pure        0     0
# 65             D_OtherGender_PermanentWorkers_TableA  pure        0     0
# 67         D_Gender_OtherThanPermanentWorkers_TableA  pure        0     0
# 68           D_Male_OtherThanPermanentWorkers_TableA  pure        0     0
# 70         D_Female_OtherThanPermanentWorkers_TableA  pure        0     0
# 72    D_OtherGender_OtherThanPermanentWorkers_TableA  pure        0     0
# 74                           D_Gender_Workers_TableA  pure        0     1
# 75                             D_Male_Workers_TableA  pure        0     1
# 77                           D_Female_Workers_TableA  pure        0     0
# 79                      D_OtherGender_Workers_TableA  pure        0     0

# %% [markdown]
# <br>
#
# Extract differently abled count

# %%
df[df['Element Name'] == 'NumberOfDifferentlyAbledEmployeesOrWorkers']
# Out:
#                                    Element Name  \
# 81   NumberOfDifferentlyAbledEmployeesOrWorkers
# 82   NumberOfDifferentlyAbledEmployeesOrWorkers
# 84   NumberOfDifferentlyAbledEmployeesOrWorkers
# 86   NumberOfDifferentlyAbledEmployeesOrWorkers
# 88   NumberOfDifferentlyAbledEmployeesOrWorkers
# 89   NumberOfDifferentlyAbledEmployeesOrWorkers
# 91   NumberOfDifferentlyAbledEmployeesOrWorkers
# 93   NumberOfDifferentlyAbledEmployeesOrWorkers
# 95   NumberOfDifferentlyAbledEmployeesOrWorkers
# 96   NumberOfDifferentlyAbledEmployeesOrWorkers
# 98   NumberOfDifferentlyAbledEmployeesOrWorkers
# 100  NumberOfDifferentlyAbledEmployeesOrWorkers
# 102  NumberOfDifferentlyAbledEmployeesOrWorkers
# 103  NumberOfDifferentlyAbledEmployeesOrWorkers
# 105  NumberOfDifferentlyAbledEmployeesOrWorkers
# 107  NumberOfDifferentlyAbledEmployeesOrWorkers
# 109  NumberOfDifferentlyAbledEmployeesOrWorkers
# 110  NumberOfDifferentlyAbledEmployeesOrWorkers
# 112  NumberOfDifferentlyAbledEmployeesOrWorkers
# 114  NumberOfDifferentlyAbledEmployeesOrWorkers
# 116  NumberOfDifferentlyAbledEmployeesOrWorkers
# 117  NumberOfDifferentlyAbledEmployeesOrWorkers
# 119  NumberOfDifferentlyAbledEmployeesOrWorkers
# 121  NumberOfDifferentlyAbledEmployeesOrWorkers
#
#                                        Period/Context  Unit Decimals Value
# 81                 D_Gender_PermanentEmployees_TableB  pure        0     1
# 82                   D_Male_PermanentEmployees_TableB  pure        0     0
# 84                 D_Female_PermanentEmployees_TableB  pure        0     1
# 86            D_OtherGender_PermanentEmployees_TableB  pure        0     0
# 88        D_Gender_OtherThanPermanentEmployees_TableB  pure        0     0
# 89          D_Male_OtherThanPermanentEmployees_TableB  pure        0     0
# 91        D_Female_OtherThanPermanentEmployees_TableB  pure        0     0
# 93   D_OtherGender_OtherThanPermanentEmployees_TableB  pure        0     0
# 95                          D_Gender_Employees_TableB  pure        0     1
# 96                            D_Male_Employees_TableB  pure        0     0
# 98                          D_Female_Employees_TableB  pure        0     1
# 100                    D_OtherGender_Employees_TableB  pure        0     0
# 102                  D_Gender_PermanentWorkers_TableB  pure        0     0
# 103                    D_Male_PermanentWorkers_TableB  pure        0     0
# 105                  D_Female_PermanentWorkers_TableB  pure        0     0
# 107             D_OtherGender_PermanentWorkers_TableB  pure        0     0
# 109         D_Gender_OtherThanPermanentWorkers_TableB  pure        0     0
# 110           D_Male_OtherThanPermanentWorkers_TableB  pure        0     0
# 112         D_Female_OtherThanPermanentWorkers_TableB  pure        0     0
# 114    D_OtherGender_OtherThanPermanentWorkers_TableB  pure        0     0
# 116                           D_Gender_Workers_TableB  pure        0     0
# 117                             D_Male_Workers_TableB  pure        0     0
# 119                           D_Female_Workers_TableB  pure        0     0
# 121                      D_OtherGender_Workers_TableB  pure        0     0

# %%
# 1. Get total employees
total_employees_row = df[(df['Element Name'] == 'NumberOfEmployeesOrWorkersIncludingDifferentlyAbled') & (df['Period/Context'] == 'D_Gender_Employees_TableA')].copy()
# Get first value in 'Value' column
total_employees_value = total_employees_row['Value'].iloc[0]

# 2. Get total differently abled employees
total_diff_employees_row = df[(df['Element Name'] == 'NumberOfDifferentlyAbledEmployeesOrWorkers') & (df['Period/Context'] == 'D_Gender_Employees_TableB')]
# Get first value in 'Value' column
total_diff_employees_value = total_diff_employees_row['Value'].iloc[0]


# 3. Get company name
company_name_row = df[(df['Element Name'] == 'NameOfTheCompany') & (df['Period/Context'] == 'ICYMain')].copy()
company_name = company_name_row['Value'].iloc[0]

print(f'Company: {company_name}')
print(f'Employees, total: {total_employees_value}')
print(f'Employees, disabled: {total_diff_employees_value}')

pd.DataFrame([[company_name, total_employees_value, total_diff_employees_value]], columns=['company', 'total', 'disabled'])
# Out:
# Company: IFCI Limited
# Employees, total: 139
# Employees, disabled: 1
#         company total disabled
# 0  IFCI Limited   139        1

# %%
'NumberOfDifferentlyAbledEmployeesOrWorkers'

# %% [markdown]
# <br>
# <br>
# <br>
#
# ## Loop through all firms

# %%
# 1. Read in file with links to all firms report files
all_firms_df = pd.read_csv('all_firm_links.csv')
all_firms_df = all_firms_df.rename(columns={'**XBRL \n': 'xml_urls'}) # Rename a column in dataframe
# all_firms_df.columns



# 2. Make new folders to hold raw XML files and parsed CSV files
import os
os.makedirs('firm_data_xml', exist_ok=True)  # Make a folder named 'firm_data_xml'
os.makedirs('firm_data_csv', exist_ok=True)  # Make a folder named 'firm_data_csv'


for x in all_firms_df['xml_urls'][:10]:
  print(x)
  #######

  # 1. Define URL to XML file
  xml_file = x.split('/')[-1]  # Get just the file name & endpoint (e.g. 'xyza.csv')

  # 2. Make GET request to fetch the XML file
  response = requests.get(x, headers={'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36'})

  # 3. Check if our request was successful (Status 200), if so, save to a file.
  if response.status_code == 200:

    # Save in folder
    with open(f'firm_data_xml/{xml_file}', 'wb') as f:
        f.write(response.content)

    print('XML (XBRL) downloaded successfully.')
  else:
    print('Failed to download file. Status code:', response.status_code)



  # 4. Extract table of values
  tree = ET.parse(xml_file)
  root = tree.getroot()

  # Structural elements to skip (not actual data facts)
  skip_tags = {
      'xbrl', 'context', 'entity', 'identifier', 'period', 'startDate',
      'endDate', 'instant', 'scenario', 'typedMember', 'unit', 'measure',
      'schemaRef', 'segment'
  }

  rows = []
  for elem in root.iter():
      # Extract local name from namespaced tag
      tag = elem.tag.split('}')[-1] if '}' in elem.tag else elem.tag

      # Skip structural elements
      if tag in skip_tags:
          continue

      # Skip domain definition elements
      if 'Domain' in tag and elem.text and 'Domain' in elem.text:
          continue

      # Get XBRL attributes
      ctx = elem.attrib.get('contextRef', '')
      unit = elem.attrib.get('unitRef', '')
      decimals = elem.attrib.get('decimals', '')

      # Only include actual facts (elements with contextRef)
      if ctx and elem.text is not None:
          rows.append({
              'Element Name': tag,
              'Period/Context': ctx,
              'Unit': unit,
              'Decimals': decimals,
              'Value': elem.text.strip()
          })

  data_temp = pd.DataFrame(rows)

  # Save to csv
  data_temp.to_csv(f'firm_data_csv/{xml_file.split('.')[0]}.csv', index=False)
  print("CSV file extracted successfully")
# Out:
# https://nsearchives.nseindia.com/corporate/xbrl/BRSR_1580445_27112025035801_WEB.xml
# XML (XBRL) downloaded successfully.
# CSV file extracted successfully
# https://nsearchives.nseindia.com/corporate/xbrl/BRSR_1579180_24112025024100_WEB.xml
# XML (XBRL) downloaded successfully.
# CSV file extracted successfully
# https://nsearchives.nseindia.com/corporate/xbrl/BRSR_1561070_30102025125314_WEB.xml
# XML (XBRL) downloaded successfully.
# CSV file extracted successfully
# https://nsearchives.nseindia.com/corporate/xbrl/BRSR_1556251_24102025034723_WEB.xml
# XML (XBRL) downloaded successfully.
# CSV file extracted successfully
# https://nsearchives.nseindia.com/corporate/xbrl/BRSR_1556193_24102025025946_WEB.xml
# XML (XBRL) downloaded successfully.
# CSV file extracted successfully
# https://nsearchives.nseindia.com/corporate/xbrl/BRSR_1550931_16102025074159_WEB.xml
# XML (XBRL) downloaded successfully.
# CSV file extracted successfully
# https://nsearchives.nseindia.com/corporate/xbrl/BRSR_1550623_16102025055155_WEB.xml
# XML (XBRL) downloaded successfully.
# CSV file extracted successfully
# https://nsearchives.nseindia.com/corporate/xbrl/BRSR_1546696_13102025071620_WEB.xml
# XML (XBRL) downloaded successfully.
# CSV file extracted successfully
# https://nsearchives.nseindia.com/corporate/xbrl/BRSR_1545952_13102025025038_WEB.xml
# XML (XBRL) downloaded successfully.
# CSV file extracted successfully
# https://nsearchives.nseindia.com/corporate/xbrl/BRSR_1541597_06102025073815_WEB.xml
# XML (XBRL) downloaded successfully.
# CSV file extracted successfully

# %% [markdown]
# Loop through all XML files:
# - extract total employees
# - extract differently abled employees.

# %%
pd.DataFrame(columns=['company', 'total', 'disabled'])
# Out:
# Empty DataFrame
# Columns: [company, total, disabled]
# Index: []

# %%
# Use `listdir` method to get a list of all files in a particular folder
all_csv_files = os.listdir('firm_data_csv') # List of files in this folder.

# Make an empty dataframe with three columns
combined_data = pd.DataFrame(columns=['company', 'total', 'disabled'])

# Loop through
for csv_file in all_csv_files:
  if csv_file == '.ipynb_checkpoints':
    continue

  # 1. Load file into dataframe (making sure to add folder before file name)
  temp_df = pd.read_csv(f'firm_data_csv/{csv_file}')

  # 2. Extract values (as we did with one company)
  # 2a. Get total employees
  total_employees_row = temp_df[(temp_df['Element Name'] == 'NumberOfEmployeesOrWorkersIncludingDifferentlyAbled') & (temp_df['Period/Context'] == 'D_Gender_Employees_TableA')].copy()
  total_employees_value = total_employees_row['Value'].iloc[0] # Get first value in 'Value' column

  # 2b. Get total differently abled employees
  total_diff_employees_row = temp_df[(temp_df['Element Name'] == 'NumberOfDifferentlyAbledEmployeesOrWorkers') & (temp_df['Period/Context'] == 'D_Gender_Employees_TableB')]
  total_diff_employees_value = total_diff_employees_row['Value'].iloc[0]

  # 2c. Get company name
  company_name_row = temp_df[(temp_df['Element Name'] == 'NameOfTheCompany') & (temp_df['Period/Context'] == 'ICYMain')].copy()
  company_name = company_name_row['Value'].iloc[0]


  # 3. Add to a combined dataframe (first make dataframe with one row, then add to combined)
  df_new_row = pd.DataFrame([[company_name, total_employees_value, total_diff_employees_value]], columns=['company', 'total', 'disabled'])
  combined_data = pd.concat([combined_data, df_new_row], ignore_index=True)

# %%
# Calculate percentage of total
combined_data['disabled'] = combined_data['disabled'].astype(int)
combined_data['total'] = combined_data['total'].astype(int)

combined_data['disabled_percent'] = combined_data['disabled'] / combined_data['total']
combined_data
# Out:
#                                         company  total  disabled  \
# 0                          BF UTILITIES LIMITED      7         0
# 1                     THE ANDHRA SUGARS LIMITED    651         3
# 2                    Sirca Paints India Limited    483         0
# 3                      Indraprastha Gas Limited    720         4
# 4  Network People Services Technologies Limited    324         1
# 5                                   HMT LIMITED     29         0
# 6                                  IFCI Limited    139         1
# 7               Accelya Solutions India Limited   1351         4
# 8                                 KIOCL Limited    249         7
# 9       THE NEW INDIA ASSURANCE COMPANY LIMITED  10951       321
#
#    disabled_percent
# 0          0.000000
# 1          0.004608
# 2          0.000000
# 3          0.005556
# 4          0.003086
# 5          0.000000
# 6          0.007194
# 7          0.002961
# 8          0.028112
# 9          0.029312

# %%
from google.colab import drive
drive.mount('/content/drive')
